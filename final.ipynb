# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\udays\OneDrive\Desktop\thales\dataset\train.csv')

# %%
df
# Out:
#           ID        Datetime  City_ID  Particulate_matter SO2_concentration  \
# 0          0  01/01/17 14:00        0                14.0             40.12
# 1          1  01/01/17 15:00        0                12.0             65.59
# 2          2  01/01/17 16:00        0                 6.0             58.87
# 3          3  01/01/17 17:00        0                 5.0             84.67
# 4          4  01/01/17 18:00        0                 5.0             83.66
# ...      ...             ...      ...                 ...               ...
# 55995  63039  13/03/20 03:00        1               103.0            232.74
# 55996  63040  13/03/20 04:00        1                75.0            241.44
# 55997  63041  13/03/20 05:00        1                63.0            220.01
# 55998  63042  13/03/20 06:00        1                60.0            206.98
# 55999  63043  13/03/20 07:00        1                64.0            210.63
#
# ...

# %%
df.isna().sum()
# Out:
# ID                      0
# Datetime                0
# City_ID                 0
# Particulate_matter    660
# SO2_concentration       0
# O3_concentration      802
# CO_concentration        0
# NO2_concentration       0
# Presure                 0
# Dew_point               0
# Precipitation           0
# Anonymous_X1          216
# Wind_speed              0
# Moisture_percent        0
# Temperature             0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#           ID        Datetime  City_ID  Particulate_matter SO2_concentration  \
# 0          0  01/01/17 14:00        0                14.0             40.12
# 1          1  01/01/17 15:00        0                12.0             65.59
# 2          2  01/01/17 16:00        0                 6.0             58.87
# 3          3  01/01/17 17:00        0                 5.0             84.67
# 4          4  01/01/17 18:00        0                 5.0             83.66
# ...      ...             ...      ...                 ...               ...
# 55995  63039  13/03/20 03:00        1               103.0            232.74
# 55996  63040  13/03/20 04:00        1                75.0            241.44
# 55997  63041  13/03/20 05:00        1                63.0            220.01
# 55998  63042  13/03/20 06:00        1                60.0            206.98
# 55999  63043  13/03/20 07:00        1                64.0            210.63
#
# ...

# %%
df.count().sum()
# Out:
# 822150

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54810 entries, 0 to 55999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  54810 non-null  int64
#  1   Datetime            54810 non-null  object
#  2   City_ID             54810 non-null  int64
#  3   Particulate_matter  54810 non-null  float64
#  4   SO2_concentration   54810 non-null  object
#  5   O3_concentration    54810 non-null  object
#  6   CO_concentration    54810 non-null  object
#  7   NO2_concentration   54810 non-null  float64
#  8   Presure             54810 non-null  float64
#  9   Dew_point           54810 non-null  float64
#  10  Precipitation       54810 non-null  float64
#  11  Anonymous_X1        54810 non-null  float64
#  12  Wind_speed          54810 non-null  float64
#  13  Moisture_percent    54810 non-null  float64
#  14  Temperature         54810 non-null  float64
# ...

# %%
df['SO2_concentration'] = pd.to_numeric(df['SO2_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
df['CO_concentration'] = pd.to_numeric(df['CO_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
df['O3_concentration'] = pd.to_numeric(df['O3_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
# df['Datetime'] = pd.to_datetime(df['Datetime'], format='%d/%m/%y %H:%M', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54810 entries, 0 to 55999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  54810 non-null  int64
#  1   Datetime            54810 non-null  object
#  2   City_ID             54810 non-null  int64
#  3   Particulate_matter  54810 non-null  float64
#  4   SO2_concentration   54810 non-null  float64
#  5   O3_concentration    54810 non-null  float64
#  6   CO_concentration    54810 non-null  float64
#  7   NO2_concentration   54810 non-null  float64
#  8   Presure             54810 non-null  float64
#  9   Dew_point           54810 non-null  float64
#  10  Precipitation       54810 non-null  float64
#  11  Anonymous_X1        54810 non-null  float64
#  12  Wind_speed          54810 non-null  float64
#  13  Moisture_percent    54810 non-null  float64
#  14  Temperature         54810 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  ID       City_ID  Particulate_matter  SO2_concentration  \
# count  54810.000000  54810.000000        54810.000000       54810.000000
# mean   31524.529246      0.500310          110.438677         154.767679
# std    19309.790391      0.500004           94.967788        1044.506448
# min        0.000000      0.000000            2.000000          10.010000
# 25%    13969.250000      0.000000           39.000000          60.852500
# 50%    35061.500000      1.000000           88.000000         129.960000
# 75%    49067.750000      1.000000          152.000000         190.477500
# max    63043.000000      1.000000          995.000000       36508.000000
#
#        O3_concentration  CO_concentration  NO2_concentration       Presure  \
# count      54810.000000      54810.000000       54810.000000  54810.000000
# mean         130.179588       3523.355661         143.492179   1012.424965
# std         1615.539424       2381.083696          76.745336     10.116633
# ...

# %%
df.head()
# Out:
#    ID        Datetime  City_ID  Particulate_matter  SO2_concentration  \
# 0   0  01/01/17 14:00        0                14.0              40.12
# 1   1  01/01/17 15:00        0                12.0              65.59
# 2   2  01/01/17 16:00        0                 6.0              58.87
# 3   3  01/01/17 17:00        0                 5.0              84.67
# 4   4  01/01/17 18:00        0                 5.0              83.66
#
#    O3_concentration  CO_concentration  NO2_concentration  Presure  Dew_point  \
# 0              85.0            600.14              38.55   1024.5      -21.4
# 1              84.0           2082.38              96.09   1025.1      -22.1
# 2              83.0           1475.88             111.09   1025.3      -24.6
# 3              84.0           2448.53              67.59   1026.2      -25.5
# 4              77.0           2224.61              95.86   1027.1      -24.5
#
#    Precipitation  Anonymous_X1  Wind_speed  Moisture_percent  Temperature
# ...

# %%
df.isna().sum()
# Out:
# ID                    0
# Datetime              0
# City_ID               0
# Particulate_matter    0
# SO2_concentration     0
# O3_concentration      0
# CO_concentration      0
# NO2_concentration     0
# Presure               0
# Dew_point             0
# Precipitation         0
# Anonymous_X1          0
# Wind_speed            0
# Moisture_percent      0
# Temperature           0
# dtype: int64

# %%
df.drop(['ID','Datetime'],axis=1,inplace=True)

# %%
df
# Out:
#        City_ID  Particulate_matter  SO2_concentration  O3_concentration  \
# 0            0                14.0              40.12              85.0
# 1            0                12.0              65.59              84.0
# 2            0                 6.0              58.87              83.0
# 3            0                 5.0              84.67              84.0
# 4            0                 5.0              83.66              77.0
# ...        ...                 ...                ...               ...
# 55995        1               103.0             232.74             128.0
# 55996        1                75.0             241.44             154.0
# 55997        1                63.0             220.01             172.0
# 55998        1                60.0             206.98             170.0
# 55999        1                64.0             210.63             165.0
#
#        CO_concentration  NO2_concentration  Presure  Dew_point  Precipitation  \
# ...

# %%
df.boxplot(figsize=(24,12))
plt.title("box plot")
plt.show()

# %%
from scipy.stats.mstats import winsorize
df['Particulate_matter'] = winsorize(df['Particulate_matter'], limits=[0.05, 0.05])
df['SO2_concentration'] = winsorize(df['SO2_concentration'], limits=[0.05, 0.05])
df['O3_concentration'] = winsorize(df['O3_concentration'], limits=[0.05, 0.05])
df['CO_concentration'] = winsorize(df['CO_concentration'], limits=[0.05, 0.05])

# %%
plt.boxplot(df['Particulate_matter'])
plt.show()

# %%
df.boxplot(figsize=(24,12))
plt.title("box plot")
plt.show()

# %%
df.corr()
# Out:
#                      City_ID  Particulate_matter  SO2_concentration  \
# City_ID             1.000000            0.000215          -0.004202
# Particulate_matter  0.000215            1.000000          -0.066707
# SO2_concentration  -0.004202           -0.066707           1.000000
# O3_concentration   -0.004153           -0.141788           0.565095
# CO_concentration    0.000230           -0.069993           0.809956
# NO2_concentration  -0.003653           -0.064137           0.886268
# Presure             0.002507           -0.071045          -0.741925
# Dew_point          -0.002234            0.128384           0.736715
# Precipitation      -0.001187           -0.026376           0.032376
# Anonymous_X1       -0.000727            0.037651           0.641409
# Wind_speed          0.000404           -0.210750           0.034220
# Moisture_percent   -0.000262            0.061820          -0.665834
# Temperature        -0.001748           -0.067820           0.892901
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr_matrix = df.corr()
plt.figure(figsize=(24, 12))

# Create the heatmap
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", vmin=-1, vmax=1)

# Display the plot
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
df.drop(['City_ID'],axis=1,inplace=True)

# %%
df.corr()
# Out:
#                     Particulate_matter  SO2_concentration  O3_concentration  \
# Particulate_matter            1.000000          -0.066707         -0.141788
# SO2_concentration            -0.066707           1.000000          0.565095
# O3_concentration             -0.141788           0.565095          1.000000
# CO_concentration             -0.069993           0.809956          0.548036
# NO2_concentration            -0.064137           0.886268          0.554065
# Presure                      -0.071045          -0.741925         -0.455206
# Dew_point                     0.128384           0.736715          0.296083
# Precipitation                -0.026376           0.032376          0.031367
# Anonymous_X1                  0.037651           0.641409          0.307313
# Wind_speed                   -0.210750           0.034220          0.324106
# Moisture_percent              0.061820          -0.665834         -0.479775
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(n_estimators=100, learning_rate=0.1, max_depth=10, random_state=42)

# %%
from sklearn.metrics import r2_score

# %%
from sklearn.model_selection import train_test_split

# %%
y=df['Temperature']

# %%
y
# Out:
# 0        -0.323
# 1        -0.570
# 2        -1.008
# 3        -1.234
# 4        -1.704
#           ...
# 55995    26.747
# 55996    28.004
# 55997    28.215
# 55998    27.864
# 55999    27.461
# Name: Temperature, Length: 54810, dtype: float64

# %%
df.drop('Temperature',axis=1,inplace=True)

# %%
x_train,x_test,y_train,y_test=train_test_split(df,y,test_size=0.3,random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred=model.predict(x_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.9738579290579655

# %% [raw]
# Model is trained now it need tesed with the test set

# %%
dt=pd.read_csv(r'C:\Users\udays\OneDrive\Desktop\thales\dataset\test.csv')

# %%
dt
# Out:
#           ID        Datetime  City_ID  Particulate_matter SO2_concentration  \
# 0      28000  13/03/20 08:00        0                74.0            245.32
# 1      28001  13/03/20 09:00        0                62.0            215.12
# 2      28002  13/03/20 10:00        0               103.0            173.38
# 3      28003  13/03/20 11:00        0               125.0            148.45
# 4      28004  13/03/20 12:00        0                89.0            159.23
# ...      ...             ...      ...                 ...               ...
# 14083  70083  01/01/21 09:00        1                51.0            110.82
# 14084  70084  01/01/21 10:00        1                45.0             87.31
# 14085  70085  01/01/21 11:00        1                58.0            139.13
# 14086  70086  01/01/21 12:00        1                53.0            104.13
# 14087  70087  01/01/21 13:00        1                71.0             84.71
#
# ...

# %%
res_df = pd.DataFrame(dt['ID'])

# %%
res_df
# Out:
#           ID
# 0      28000
# 1      28001
# 2      28002
# 3      28003
# 4      28004
# ...      ...
# 14083  70083
# 14084  70084
# 14085  70085
# 14086  70086
# 14087  70087
#
# [14088 rows x 1 columns]

# %%
dt.drop(['ID','Datetime','City_ID'],axis=1,inplace=True)

# %%
dt
# Out:
#        Particulate_matter SO2_concentration O3_concentration CO_concentration  \
# 0                    74.0            245.32              162          6417.29
# 1                    62.0            215.12              154          5056.86
# 2                   103.0            173.38              144          5083.63
# 3                   125.0            148.45              140          6858.93
# 4                    89.0            159.23              142          6435.99
# ...                   ...               ...              ...              ...
# 14083                51.0            110.82               73          2103.88
# 14084                45.0             87.31               54          4427.54
# 14085                58.0            139.13               28          3060.49
# 14086                53.0            104.13               15           2367.7
# 14087                71.0             84.71                4          1495.21
#
# ...

# %%
df.isna().sum()
# Out:
# Particulate_matter    0
# SO2_concentration     0
# O3_concentration      0
# CO_concentration      0
# NO2_concentration     0
# Presure               0
# Dew_point             0
# Precipitation         0
# Anonymous_X1          0
# Wind_speed            0
# Moisture_percent      0
# dtype: int64

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14088 entries, 0 to 14087
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Particulate_matter  13755 non-null  float64
#  1   SO2_concentration   14088 non-null  object
#  2   O3_concentration    13722 non-null  object
#  3   CO_concentration    14088 non-null  object
#  4   NO2_concentration   14088 non-null  float64
#  5   Presure             14088 non-null  float64
#  6   Dew_point           14088 non-null  float64
#  7   Precipitation       14088 non-null  float64
#  8   Anonymous_X1        14024 non-null  float64
#  9   Wind_speed          14088 non-null  float64
#  10  Moisture_percent    14088 non-null  float64
# dtypes: float64(8), object(3)
# memory usage: 1.2+ MB

# %%
dt['SO2_concentration'] = pd.to_numeric(dt['SO2_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
dt['O3_concentration'] = pd.to_numeric(dt['O3_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
dt['CO_concentration'] = pd.to_numeric(dt['CO_concentration'].replace(r'[^0-9.]', '', regex=True), errors='coerce')

# %%
dt = dt.fillna(dt.mean())

# %%
y_pred=model.predict(dt)

# %%
res_df['Temperature']=y_pred

# %%
res_df
# Out:
#           ID  Temperature
# 0      28000    28.243837
# 1      28001    28.543442
# 2      28002    23.422464
# 3      28003    22.817356
# 4      28004    23.615894
# ...      ...          ...
# 14083  70083    12.192142
# 14084  70084    11.663242
# 14085  70085    15.208631
# 14086  70086    11.939263
# 14087  70087     2.868410
#
# [14088 rows x 2 columns]

# %%
import os

# Save the DataFrame to a CSV file on the desktop
desktop_path = os.path.join(os.path.expanduser("~"), r"C:\Users\udays\OneDrive\Desktop", "submit5.csv")
res_df.to_csv(desktop_path, index=False)

print(f"File saved to: {desktop_path}")
# Out:
# File saved to: C:\Users\udays\OneDrive\Desktop\submit5.csv
